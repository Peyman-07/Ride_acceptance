# %%
import os, sys # add MaaSSim to path (not needed if MaaSSim is already in path)
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import MaaSSim

# %%
#!pip install MaaSSim
import MaaSSim.utils
import logging
from dotmap import DotMap
import MaaSSim.simulators
from MaaSSim.data_structures import structures as inData
from MaaSSim.acceptance import ResultS

# %%
import osmnx as ox
import networkx as nx
import random
import pandas as pd
import matplotlib.pyplot as plt          
import numpy as np
import seaborn as sns

# %%
# Do not forget to set the radius for centeral nodes calculation
# The minimum trip distance is considered 1000m and this can be modified through utils.py: generate_demand function. 
# long attribute should be calculated according to the size of city
# Platform fare is 2$ per km

params = MaaSSim.utils.get_config('glance.json')
params.use_fixed_postions = True
params.times.patience = 600 #in second
params.dist_threshold = 10000 #in meter
params.vehicle_fixed_positions= True  #this should be fixed
params.city = "Delft, Netherlands"
params.paths.G = "../../data/graphs/Delft.graphml"
params.paths.skim = "../../data/graphs/Delft.csv"
params.paths.ride_skim = "../../data/graphs/Delft_ride.csv"
params.nP = 500
params.nV = 20
params.simTime = 5

# %%
sim= MaaSSim.simulators.simulate(params=params, logger_level=logging.WARNING)
# Out:
# 20-11-21 17:05:19-WARNING-Setting up 5h simulation at 2021-11-20 14:35:28 for 20 vehicles and 500 passengers in Delft, Netherlands
# 20-11-21 17:05:27-WARNING-simulation time 8.5 s
# 20-11-21 17:05:28-WARNING-assertion tests for simulation results - passed

# %%
#No need to run
G = sim.inData.G
fig, ax = ox.plot_graph(G, figsize=(10, 10), show=False, close=False, node_size=20, bgcolor='black', edge_color='w')

# %%
#No need to run
centeral_nodes = sim.inData.stats.central_nodes

l_x=[]
l_y=[]

for i in centeral_nodes:
    l_x.append(sim.inData.G.nodes[i]['x'])
    l_y.append(sim.inData.G.nodes[i]['y'])

print('Number of centeral nodes: ', len(l_x))

fig, ax = ox.plot_graph(sim.inData.G, figsize=(10, 10), node_size=5, edge_linewidth=0.3,
                            show=False, close=False, node_color='aquamarine',
                            edge_color='white', bgcolor='black')

scat = plt.scatter(x=l_x, y=l_y,c='aqua',linewidths=0.5, label='Centeral nodes')
#scat = plt.scatter(x=l_x, y=l_y,c='tab:red',linewidths=1)
scat = plt.scatter(x=sim.inData.G.nodes[sim.inData.stats.center]['x'], 
                   y=sim.inData.G.nodes[sim.inData.stats.center]['y'],c='red',linewidths=5,
                   label='Center')

plt.legend()
# Out:
# Number of centeral nodes:  173

# %%
vehicles_position = sim.vehicle_fixed_positions
veh_lx=[]
veh_ly=[]
for i in vehicles_position:
    veh_lx.append(sim.inData.G.nodes[i]['x'])
    veh_ly.append(sim.inData.G.nodes[i]['y'])
    
passengers_position = sim.inData.passengers.pos
pass_lx=[]
pass_ly=[]
for i in passengers_position:
    pass_lx.append(sim.inData.G.nodes[i]['x'])
    pass_ly.append(sim.inData.G.nodes[i]['y'])

fig, ax = ox.plot_graph(sim.inData.G, figsize=(20, 20), node_size=5, edge_linewidth=0.3,
                            show=False, close=False, node_color='aquamarine',
                            edge_color='white', bgcolor='black')

scat = plt.scatter(x=veh_lx, y=veh_ly,c='red',linewidths=0.5, label='Vehicles')
scat = plt.scatter(x=pass_lx, y=pass_ly,c='yellow',linewidths=0.5, label='Passengers')
#scat = plt.scatter(x=l_x, y=l_y,c='tab:red',linewidths=1)
scat = plt.scatter(x=sim.inData.G.nodes[sim.inData.stats.center]['x'], 
                   y=sim.inData.G.nodes[sim.inData.stats.center]['y'],c='aqua',linewidths=5,
                   label='Center')

plt.legend()

# %%
r_def= ResultS(sim)

# %%
import numpy as np
import pandas as pd
import math
import random as random
from dotmap import DotMap


def f_decline(veh, **kwargs):
    

    df = pd.DataFrame(veh.myrides)
    ASC = 1.810                                                                                   #ASC
    
    working_shift = sim.params.simTime*3600 - veh.veh['shift_start']                               #Time1_loc
    T1 = int(working_shift/3)
    request_time = df[df['event']=='RECEIVES_REQUEST'].iloc[-1]['t']
    
    if  request_time in range(veh.veh['shift_start'], veh.veh['shift_start']+T1):
        Time1 = 1
    else:
        Time1 = 0
        
    if veh.veh['pos'] in sim.inData.stats.central_nodes:
        loc = 1
    else:
        loc = 0
        
        
    d = veh.offers[0]['request']["origin"]                                                       #pickup_time
    o = veh.veh.pos
    pickup_time = veh.sim.skims.ride[o][d]/60  #minutes
      
    t = df[df['event']=='RECEIVES_REQUEST'].iloc[-1]['t']                                        #waiting_time
    
    if 'ARRIVES_AT_DROPOFF' in df['event'].unique():
        t0 = df[df['event']=='ARRIVES_AT_DROPOFF'].iloc[-1]['t']
    else:
        t0 = df[df['event']=='OPENS_APP'].iloc[-1]['t']
    waiting_time = (t - t0)/60 #minutes 
    
    surge_price = 0                                                                               #surge_price
    
    req = 1                         #req                                                          #req_long_rate_dec
    
    if (veh.offers[0]["request"]["dist"]/sim.params.speeds.ride)/60 > 6.5: #long
        long = 1
    else:
        long = 0
        
    rate = sim.pax[veh.offers[0]['pax_id']].pax.get('rate',5)   #rate
    
    if len(veh.declines.index) == 0:          #dec
        last_declined = 'False'
    else:
        last_declined = veh.declines.loc[len(veh.declines.index)-1]['declined']
        
    if last_declined == 'True':
        dec = 1
    else:
        dec = 0
        
           
    V = ((ASC*1) + (Time1*loc*(-0.303)) + (pickup_time*(-0.050)) + (waiting_time*(-0.017)) + 
        ((req*long*rate*dec)*0.091) + (surge_price*0.101))
    
    
    acc_prob = (math.exp(V))/(1+math.exp(V))

    attr = pd.DataFrame({'pax_id':[veh.offers[0]['pax_id']], 'veh_id':[veh.id], 'Time1':Time1,  
                             'loc':loc, 'Time1_loc':[Time1*loc*(-0.303)], 'pickup_time':[pickup_time*(-0.050)],
                             'waiting_t':[waiting_time], 'surge_price':[surge_price*0.101], 
                             'req_long_rate_dec':[req*long*rate*dec*0.091], 'req':1, 'long':long, 
                             'rate':rate, 'dec':dec, 'P':[acc_prob]})
    sim.acceptance_attributes = pd.concat([sim.acceptance_attributes,attr])

    
    if acc_prob > random.uniform(0, 1):
        return False
    else:
        return True
    


sim.make_and_run(f_driver_decline=f_decline)
# Out:
# 20-11-21 17:10:21-WARNING-pax    7  got rejected by vehicle 16               2021-11-20 14:42:51
# 20-11-21 17:10:22-WARNING-pax   15  got rejected by vehicle 4                2021-11-20 14:47:36
# 20-11-21 17:10:22-WARNING-pax   21  got rejected by vehicle 5                2021-11-20 14:52:02
# 20-11-21 17:10:22-WARNING-pax   22  got rejected by vehicle 12               2021-11-20 14:52:03
# 20-11-21 17:10:22-WARNING-pax   28  got rejected by vehicle 19               2021-11-20 14:55:32
# 20-11-21 17:10:22-WARNING-pax   40  got rejected by vehicle 15               2021-11-20 15:04:34
# 20-11-21 17:10:22-WARNING-pax   51  got rejected by vehicle 3                2021-11-20 15:11:58
# 20-11-21 17:10:22-WARNING-pax   51  got rejected by vehicle 9                2021-11-20 15:11:58
# 20-11-21 17:10:23-WARNING-pax   59  got rejected by vehicle 16               2021-11-20 15:16:25
# 20-11-21 17:10:23-WARNING-pax   63  got rejected by vehicle 15               2021-11-20 15:21:18
# 20-11-21 17:10:23-WARNING-pax   69  got rejected by vehicle 19               2021-11-20 15:23:26
# 20-11-21 17:10:23-WARNING-pax   79  got rejected by vehicle 2                2021-11-20 15:27:20
# 20-11-21 17:10:23-WARNING-pax   98  got rejected by vehicle 6                2021-11-20 15:36:48
# 20-11-21 17:10:23-WARNING-pax   98  got rejected by vehicle 15               2021-11-20 15:36:48
# 20-11-21 17:10:23-WARNING-Nobody likes each other, Qs 2veh; 1req; tabu 15
# 20-11-21 17:10:24-WARNING-pax  102  got rejected by vehicle 7                2021-11-20 15:40:41
# 20-11-21 17:10:24-WARNING-pax  107  got rejected by vehicle 2                2021-11-20 15:42:52
# 20-11-21 17:10:24-WARNING-pax  111  got rejected by vehicle 15               2021-11-20 15:45:00
# 20-11-21 17:10:24-WARNING-pax  111  got rejected by vehicle 2                2021-11-20 15:45:00
# 20-11-21 17:10:24-WARNING-pax  120  got rejected by vehicle 18               2021-11-20 15:50:59
# 20-11-21 17:10:24-WARNING-pax  122  got rejected by vehicle 6                2021-11-20 15:51:29
# 20-11-21 17:10:24-WARNING-pax  126  got rejected by vehicle 9                2021-11-20 15:52:43
# 20-11-21 17:10:24-WARNING-pax  127  got rejected by vehicle 9                2021-11-20 15:52:54
# 20-11-21 17:10:24-WARNING-pax  130  got rejected by vehicle 14               2021-11-20 15:53:56
# 20-11-21 17:10:24-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 24
# 20-11-21 17:10:24-WARNING-pax  130  got rejected by vehicle 3                2021-11-20 15:54:16
# 20-11-21 17:10:24-WARNING-Nobody likes each other, Qs 2veh; 1req; tabu 25
# 20-11-21 17:10:24-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 25
# 20-11-21 17:10:24-WARNING-pax  135  got rejected by vehicle 12               2021-11-20 15:57:27
# 20-11-21 17:10:24-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 26
# 20-11-21 17:10:24-WARNING-pax  136  got rejected by vehicle 10               2021-11-20 15:57:40
# 20-11-21 17:10:24-WARNING-pax  139  got rejected by vehicle 10               2021-11-20 15:59:00
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 5                2021-11-20 16:05:19
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 10               2021-11-20 16:05:19
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 2                2021-11-20 16:05:19
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 18               2021-11-20 16:05:19
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 20               2021-11-20 16:05:19
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 13               2021-11-20 16:05:19
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 6veh; 1req; tabu 34
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 19               2021-11-20 16:05:39
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 7veh; 1req; tabu 35
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 6veh; 1req; tabu 35
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 5veh; 1req; tabu 35
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 8                2021-11-20 16:06:43
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 6veh; 1req; tabu 36
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 5veh; 1req; tabu 36
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 7                2021-11-20 16:06:44
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 6veh; 1req; tabu 37
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 11               2021-11-20 16:06:46
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 7veh; 1req; tabu 38
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 15               2021-11-20 16:06:52
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 8veh; 1req; tabu 39
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 17               2021-11-20 16:07:27
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 9veh; 1req; tabu 40
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 10veh; 1req; tabu 40
# 20-11-21 17:10:25-WARNING-pax  148  got rejected by vehicle 7                2021-11-20 16:08:27
# 20-11-21 17:10:25-WARNING-pax  148  got rejected by vehicle 19               2021-11-20 16:08:27
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 9veh; 1req; tabu 42
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 8veh; 1req; tabu 42
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 9veh; 1req; tabu 42
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 14               2021-11-20 16:09:32
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 10veh; 1req; tabu 43
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 9veh; 1req; tabu 43
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 1                2021-11-20 16:10:01
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 10veh; 1req; tabu 44
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 9veh; 1req; tabu 44
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 16               2021-11-20 16:10:28
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 10veh; 1req; tabu 45
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 8                2021-11-20 16:10:32
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 11veh; 1req; tabu 46
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 10veh; 1req; tabu 46
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 4                2021-11-20 16:11:09
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 11veh; 1req; tabu 47
# 20-11-21 17:10:25-WARNING-pax  153  got rejected by vehicle 18               2021-11-20 16:11:36
# 20-11-21 17:10:25-WARNING-pax  153  got rejected by vehicle 17               2021-11-20 16:11:36
# 20-11-21 17:10:25-WARNING-pax  153  got rejected by vehicle 2                2021-11-20 16:11:36
# 20-11-21 17:10:25-WARNING-pax  153  got rejected by vehicle 11               2021-11-20 16:11:36
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 10veh; 1req; tabu 51
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 12               2021-11-20 16:12:25
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 11veh; 1req; tabu 52
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 10veh; 1req; tabu 52
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 20               2021-11-20 16:13:56
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 11veh; 1req; tabu 53
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 10               2021-11-20 16:14:25
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 12veh; 1req; tabu 54
# 20-11-21 17:10:25-WARNING-pax  155  got rejected by vehicle 17               2021-11-20 16:14:35
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 11veh; 1req; tabu 55
# 20-11-21 17:10:25-WARNING-pax  144  got rejected by vehicle 9                2021-11-20 16:14:39
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 12veh; 1req; tabu 56
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 11veh; 1req; tabu 56
# 20-11-21 17:10:25-WARNING-Nobody likes each other, Qs 10veh; 1req; tabu 56
# 20-11-21 17:10:25-WARNING-pax  158  got rejected by vehicle 16               2021-11-20 16:15:39
# 20-11-21 17:10:25-WARNING-pax  162  got rejected by vehicle 4                2021-11-20 16:19:20
# 20-11-21 17:10:26-WARNING-pax  173  got rejected by vehicle 12               2021-11-20 16:24:36
# 20-11-21 17:10:26-WARNING-pax  183  got rejected by vehicle 6                2021-11-20 16:28:25
# 20-11-21 17:10:26-WARNING-pax  184  got rejected by vehicle 6                2021-11-20 16:28:40
# 20-11-21 17:10:26-WARNING-pax  185  got rejected by vehicle 17               2021-11-20 16:28:56
# 20-11-21 17:10:26-WARNING-pax  191  got rejected by vehicle 18               2021-11-20 16:32:19
# 20-11-21 17:10:26-WARNING-pax  198  got rejected by vehicle 10               2021-11-20 16:37:52
# 20-11-21 17:10:26-WARNING-pax  198  got rejected by vehicle 11               2021-11-20 16:37:52
# 20-11-21 17:10:26-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 65
# 20-11-21 17:10:26-WARNING-pax  207  got rejected by vehicle 5                2021-11-20 16:42:22
# 20-11-21 17:10:26-WARNING-pax  211  got rejected by vehicle 11               2021-11-20 16:42:31
# 20-11-21 17:10:27-WARNING-pax  215  got rejected by vehicle 14               2021-11-20 16:44:29
# 20-11-21 17:10:27-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 68
# 20-11-21 17:10:27-WARNING-pax  226  got rejected by vehicle 15               2021-11-20 16:55:52
# 20-11-21 17:10:27-WARNING-pax  228  got rejected by vehicle 3                2021-11-20 16:56:48
# 20-11-21 17:10:27-WARNING-pax  230  got rejected by vehicle 13               2021-11-20 16:57:19
# 20-11-21 17:10:27-WARNING-pax  230  got rejected by vehicle 17               2021-11-20 16:57:19
# 20-11-21 17:10:27-WARNING-pax  234  got rejected by vehicle 11               2021-11-20 16:59:50
# 20-11-21 17:10:27-WARNING-pax  234  got rejected by vehicle 12               2021-11-20 16:59:50
# 20-11-21 17:10:27-WARNING-pax  244  got rejected by vehicle 19               2021-11-20 17:03:53
# 20-11-21 17:10:27-WARNING-pax  246  got rejected by vehicle 20               2021-11-20 17:04:30
# 20-11-21 17:10:27-WARNING-pax  246  got rejected by vehicle 19               2021-11-20 17:04:30
# 20-11-21 17:10:27-WARNING-Nobody likes each other, Qs 2veh; 1req; tabu 77
# 20-11-21 17:10:27-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 77
# 20-11-21 17:10:27-WARNING-pax  249  got rejected by vehicle 12               2021-11-20 17:05:59
# 20-11-21 17:10:27-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 78
# 20-11-21 17:10:27-WARNING-pax  249  got rejected by vehicle 18               2021-11-20 17:05:59
# 20-11-21 17:10:27-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 79
# 20-11-21 17:10:27-WARNING-pax  249  got rejected by vehicle 10               2021-11-20 17:06:13
# 20-11-21 17:10:27-WARNING-Nobody likes each other, Qs 2veh; 1req; tabu 80
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 5                2021-11-20 17:06:28
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 3veh; 1req; tabu 81
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 7                2021-11-20 17:06:32
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 4veh; 1req; tabu 82
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 16               2021-11-20 17:06:46
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 5veh; 1req; tabu 83
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 3                2021-11-20 17:06:57
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 6veh; 1req; tabu 84
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 5veh; 1req; tabu 84
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 14               2021-11-20 17:07:51
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 6veh; 1req; tabu 85
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 5veh; 1req; tabu 85
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 4veh; 1req; tabu 85
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 6                2021-11-20 17:08:46
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 5veh; 1req; tabu 86
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 4                2021-11-20 17:09:34
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 6veh; 1req; tabu 87
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 15               2021-11-20 17:09:39
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 7veh; 1req; tabu 88
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 9                2021-11-20 17:09:53
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 8veh; 1req; tabu 89
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 19               2021-11-20 17:10:19
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 9veh; 1req; tabu 90
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 8veh; 1req; tabu 90
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 7veh; 1req; tabu 90
# 20-11-21 17:10:28-WARNING-pax  256  got rejected by vehicle 14               2021-11-20 17:11:07
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 6veh; 1req; tabu 91
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 5veh; 1req; tabu 91
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 8                2021-11-20 17:11:14
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 6veh; 1req; tabu 92
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 1                2021-11-20 17:11:38
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 7veh; 1req; tabu 93
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 6veh; 1req; tabu 93
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 5veh; 1req; tabu 93
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 5                2021-11-20 17:13:23
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 6veh; 1req; tabu 94
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 11               2021-11-20 17:13:29
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 7veh; 1req; tabu 95
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 12               2021-11-20 17:14:37
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 8veh; 1req; tabu 96
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 7                2021-11-20 17:15:00
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 9veh; 1req; tabu 97
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 13               2021-11-20 17:15:18
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 10veh; 1req; tabu 98
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 3                2021-11-20 17:15:22
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 11veh; 1req; tabu 99
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 10veh; 1req; tabu 99
# 20-11-21 17:10:28-WARNING-pax  249  got rejected by vehicle 17               2021-11-20 17:15:42
# 20-11-21 17:10:28-WARNING-Nobody likes each other, Qs 11veh; 1req; tabu 100
# 20-11-21 17:10:28-WARNING-pax  266  got rejected by vehicle 13               2021-11-20 17:19:38
# 20-11-21 17:10:28-WARNING-pax  267  got rejected by vehicle 13               2021-11-20 17:19:43
# 20-11-21 17:10:28-WARNING-pax  270  got rejected by vehicle 12               2021-11-20 17:20:45
# 20-11-21 17:10:28-WARNING-pax  276  got rejected by vehicle 8                2021-11-20 17:23:30
# 20-11-21 17:10:29-WARNING-pax  284  got rejected by vehicle 20               2021-11-20 17:28:05
# 20-11-21 17:10:29-WARNING-pax  287  got rejected by vehicle 12               2021-11-20 17:29:24
# 20-11-21 17:10:29-WARNING-pax  305  got rejected by vehicle 16               2021-11-20 17:40:12
# 20-11-21 17:10:29-WARNING-pax  308  got rejected by vehicle 16               2021-11-20 17:41:01
# 20-11-21 17:10:30-WARNING-pax  326  got rejected by vehicle 18               2021-11-20 17:52:07
# 20-11-21 17:10:30-WARNING-pax  326  got rejected by vehicle 13               2021-11-20 17:52:07
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 13               2021-11-20 17:52:24
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 18               2021-11-20 17:52:24
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 17               2021-11-20 17:52:24
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 11               2021-11-20 17:52:24
# 20-11-21 17:10:30-WARNING-Nobody likes each other, Qs 4veh; 1req; tabu 114
# 20-11-21 17:10:30-WARNING-Nobody likes each other, Qs 3veh; 1req; tabu 114
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 6                2021-11-20 17:52:37
# 20-11-21 17:10:30-WARNING-Nobody likes each other, Qs 4veh; 1req; tabu 115
# 20-11-21 17:10:30-WARNING-Nobody likes each other, Qs 3veh; 1req; tabu 115
# 20-11-21 17:10:30-WARNING-pax  332  got rejected by vehicle 6                2021-11-20 17:52:59
# 20-11-21 17:10:30-WARNING-Nobody likes each other, Qs 2veh; 1req; tabu 116
# 20-11-21 17:10:30-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 116
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 2                2021-11-20 17:53:50
# 20-11-21 17:10:30-WARNING-Nobody likes each other, Qs 2veh; 1req; tabu 117
# 20-11-21 17:10:30-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 117
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 7                2021-11-20 17:55:04
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 5                2021-11-20 17:56:08
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 20               2021-11-20 17:56:31
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 12               2021-11-20 17:56:31
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 10               2021-11-20 17:59:38
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 18               2021-11-20 18:00:02
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 11               2021-11-20 18:00:05
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 9                2021-11-20 18:00:11
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 17               2021-11-20 18:01:19
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 16               2021-11-20 18:01:35
# 20-11-21 17:10:30-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 127
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 5                2021-11-20 18:02:15
# 20-11-21 17:10:30-WARNING-Nobody likes each other, Qs 2veh; 1req; tabu 128
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 8                2021-11-20 18:02:16
# 20-11-21 17:10:30-WARNING-Nobody likes each other, Qs 3veh; 1req; tabu 129
# 20-11-21 17:10:30-WARNING-pax  329  got rejected by vehicle 4                2021-11-20 18:02:28
# 20-11-21 17:10:30-WARNING-Nobody likes each other, Qs 4veh; 1req; tabu 130
# 20-11-21 17:10:30-WARNING-pax  355  got rejected by vehicle 14               2021-11-20 18:05:07
# 20-11-21 17:10:31-WARNING-pax  363  got rejected by vehicle 2                2021-11-20 18:07:55
# 20-11-21 17:10:31-WARNING-pax  370  got rejected by vehicle 20               2021-11-20 18:12:18
# 20-11-21 17:10:31-WARNING-pax  370  got rejected by vehicle 7                2021-11-20 18:12:18
# 20-11-21 17:10:31-WARNING-Nobody likes each other, Qs 2veh; 1req; tabu 134
# 20-11-21 17:10:31-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 134
# 20-11-21 17:10:31-WARNING-Nobody likes each other, Qs 1veh; 2req; tabu 134
# 20-11-21 17:10:31-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 134
# 20-11-21 17:10:31-WARNING-pax  379  got rejected by vehicle 10               2021-11-20 18:17:55
# 20-11-21 17:10:31-WARNING-pax  383  got rejected by vehicle 10               2021-11-20 18:18:55
# 20-11-21 17:10:31-WARNING-pax  390  got rejected by vehicle 15               2021-11-20 18:26:32
# 20-11-21 17:10:31-WARNING-pax  390  got rejected by vehicle 16               2021-11-20 18:26:32
# 20-11-21 17:10:32-WARNING-pax  402  got rejected by vehicle 4                2021-11-20 18:37:33
# 20-11-21 17:10:32-WARNING-pax  403  got rejected by vehicle 10               2021-11-20 18:37:46
# 20-11-21 17:10:32-WARNING-pax  405  got rejected by vehicle 13               2021-11-20 18:38:21
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 7                2021-11-20 18:40:58
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 20               2021-11-20 18:40:58
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 5                2021-11-20 18:40:58
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 16               2021-11-20 18:40:58
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 18               2021-11-20 18:40:58
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 17               2021-11-20 18:40:58
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 14               2021-11-20 18:40:58
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 8                2021-11-20 18:40:58
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 3                2021-11-20 18:40:58
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 9                2021-11-20 18:40:58
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 13               2021-11-20 18:40:58
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 11veh; 1req; tabu 152
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 10veh; 1req; tabu 152
# 20-11-21 17:10:32-WARNING-pax  410  got rejected by vehicle 17               2021-11-20 18:42:01
# 20-11-21 17:10:32-WARNING-pax  410  got rejected by vehicle 16               2021-11-20 18:42:01
# 20-11-21 17:10:32-WARNING-pax  410  got rejected by vehicle 3                2021-11-20 18:42:01
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 9veh; 1req; tabu 155
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 2                2021-11-20 18:42:01
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 10veh; 1req; tabu 156
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 11               2021-11-20 18:42:14
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 11veh; 1req; tabu 157
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 4                2021-11-20 18:42:22
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 12veh; 1req; tabu 158
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 11veh; 1req; tabu 158
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 10veh; 1req; tabu 158
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 6                2021-11-20 18:43:38
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 11veh; 1req; tabu 159
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 10veh; 1req; tabu 159
# 20-11-21 17:10:32-WARNING-pax  414  got rejected by vehicle 7                2021-11-20 18:43:44
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 9veh; 1req; tabu 160
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 15               2021-11-20 18:43:53
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 10veh; 1req; tabu 161
# 20-11-21 17:10:32-WARNING-pax  415  got rejected by vehicle 5                2021-11-20 18:44:00
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 9veh; 1req; tabu 162
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 8veh; 1req; tabu 162
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 12               2021-11-20 18:44:24
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 9veh; 1req; tabu 163
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 8veh; 1req; tabu 163
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 19               2021-11-20 18:45:00
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 9veh; 1req; tabu 164
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 8veh; 1req; tabu 164
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 10               2021-11-20 18:45:39
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 9veh; 1req; tabu 165
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 8veh; 1req; tabu 165
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 18               2021-11-20 18:46:31
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 9veh; 1req; tabu 166
# 20-11-21 17:10:32-WARNING-pax  420  got rejected by vehicle 10               2021-11-20 18:47:18
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 8veh; 1req; tabu 167
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 7veh; 1req; tabu 167
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 6veh; 1req; tabu 167
# 20-11-21 17:10:32-WARNING-pax  423  got rejected by vehicle 10               2021-11-20 18:47:39
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 5veh; 1req; tabu 168
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 20               2021-11-20 18:48:31
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 6veh; 1req; tabu 169
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 5veh; 1req; tabu 169
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 4veh; 1req; tabu 169
# 20-11-21 17:10:32-WARNING-pax  408  got rejected by vehicle 1                2021-11-20 18:49:21
# 20-11-21 17:10:32-WARNING-Nobody likes each other, Qs 5veh; 1req; tabu 170
# 20-11-21 17:10:33-WARNING-pax  408  got rejected by vehicle 6                2021-11-20 18:50:10
# 20-11-21 17:10:33-WARNING-Nobody likes each other, Qs 6veh; 1req; tabu 171
# 20-11-21 17:10:33-WARNING-Nobody likes each other, Qs 5veh; 1req; tabu 171
# 20-11-21 17:10:33-WARNING-Nobody likes each other, Qs 4veh; 1req; tabu 171
# 20-11-21 17:10:33-WARNING-Nobody likes each other, Qs 3veh; 1req; tabu 171
# 20-11-21 17:10:33-WARNING-Nobody likes each other, Qs 2veh; 1req; tabu 171
# 20-11-21 17:10:33-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 171
# 20-11-21 17:10:33-WARNING-pax  408  got rejected by vehicle 9                2021-11-20 18:50:49
# 20-11-21 17:10:33-WARNING-Nobody likes each other, Qs 2veh; 1req; tabu 172
# 20-11-21 17:10:33-WARNING-pax  408  got rejected by vehicle 8                2021-11-20 18:50:53
# 20-11-21 17:10:33-WARNING-Nobody likes each other, Qs 3veh; 1req; tabu 173
# 20-11-21 17:10:33-WARNING-pax  431  got rejected by vehicle 8                2021-11-20 18:51:28
# 20-11-21 17:10:33-WARNING-pax  448  got rejected by vehicle 6                2021-11-20 19:03:53
# 20-11-21 17:10:33-WARNING-pax  449  got rejected by vehicle 1                2021-11-20 19:04:26
# 20-11-21 17:10:33-WARNING-pax  454  got rejected by vehicle 8                2021-11-20 19:10:55
# 20-11-21 17:10:33-WARNING-pax  463  got rejected by vehicle 1                2021-11-20 19:16:47
# 20-11-21 17:10:34-WARNING-pax  474  got rejected by vehicle 11               2021-11-20 19:23:05
# 20-11-21 17:10:34-WARNING-pax  482  got rejected by vehicle 3                2021-11-20 19:25:32
# 20-11-21 17:10:34-WARNING-pax  484  got rejected by vehicle 13               2021-11-20 19:26:23
# 20-11-21 17:10:34-WARNING-pax  487  got rejected by vehicle 9                2021-11-20 19:32:39
# 20-11-21 17:10:34-WARNING-pax  487  got rejected by vehicle 3                2021-11-20 19:32:39
# 20-11-21 17:10:34-WARNING-pax  489  got rejected by vehicle 9                2021-11-20 19:32:52
# 20-11-21 17:10:34-WARNING-pax  489  got rejected by vehicle 3                2021-11-20 19:32:52
# 20-11-21 17:10:34-WARNING-pax  491  got rejected by vehicle 5                2021-11-20 19:33:30
# 20-11-21 17:10:34-WARNING-simulation time 13.3 s
# 20-11-21 17:10:35-WARNING-assertion tests for simulation results - passed

# %%
r_homo= ResultS(sim)

# %%
df = r_homo.requests
df['z'] = df['n_of_requests']*df['acceptance_rate %']
ave_p = df['z'].sum()/df['n_of_requests'].sum()/100
ave_p
# Out:
# 0.7283406754772394

# %%
# 50% & 50% Primary BIP implemented on First regime 
import numpy as np
import pandas as pd
import math
import random as random
from dotmap import DotMap

sim.acceptance_attributes = pd.DataFrame()

def f_decline(veh, **kwargs):
    
    if veh.id > (sim.params.nV/2):
    #if veh.id < (sim.params.nV/2)+1:
        if random.uniform(0, 1) > ave_p:
            return True
        else:
            return False
    else:
        df = pd.DataFrame(veh.myrides)
        ASC = 1.810                                                                                   #ASC
    
        working_shift = sim.params.simTime*3600 - veh.veh['shift_start']                               #Time1_loc
        T1 = int(working_shift/3)
        request_time = df[df['event']=='RECEIVES_REQUEST'].iloc[-1]['t']

        if  request_time in range(veh.veh['shift_start'], veh.veh['shift_start']+T1):
            Time1 = 1
        else:
            Time1 = 0

        if veh.veh['pos'] in sim.inData.stats.central_nodes:
            loc = 1
        else:
            loc = 0
        
        
        d = veh.offers[0]['request']["origin"]                                                       #pickup_time
        o = veh.veh.pos
        pickup_time = veh.sim.skims.ride[o][d]/60  #minutes
      
        t = df[df['event']=='RECEIVES_REQUEST'].iloc[-1]['t']                                        #waiting_time
    
        if 'ARRIVES_AT_DROPOFF' in df['event'].unique():
            t0 = df[df['event']=='ARRIVES_AT_DROPOFF'].iloc[-1]['t']
        else:
            t0 = df[df['event']=='OPENS_APP'].iloc[-1]['t']
        waiting_time = (t - t0)/60 #minutes 
    
        surge_price = 0                                                                               #surge_price
    
        req = 1                         #req                                                          #req_long_rate_dec
    
        if (veh.offers[0]["request"]["dist"]/sim.params.speeds.ride)/60 > 6.5: #long
            long = 1
        else:
            long = 0
        
        rate = sim.pax[veh.offers[0]['pax_id']].pax.get('rate',5)   #rate
    
        if len(veh.declines.index) == 0:          #dec
            last_declined = 'False'
        else:
            last_declined = veh.declines.loc[len(veh.declines.index)-1]['declined']
        
        if last_declined == 'True':
            dec = 1
        else:
            dec = 0
        
           
        V = ((ASC*1) + (Time1*loc*(-0.303)) + (pickup_time*(-0.050)) + (waiting_time*(-0.017)) + 
            ((req*long*rate*dec)*0.091) + (surge_price*0.101))
    
    
        acc_prob = (math.exp(V))/(1+math.exp(V))

        attr = pd.DataFrame({'pax_id':[veh.offers[0]['pax_id']], 'veh_id':[veh.id], 'Time1':Time1,  
                             'loc':loc, 'Time1_loc':[Time1*loc*(-0.303)], 'pickup_time':[pickup_time*(-0.050)],
                             'waiting_t':[waiting_time], 'surge_price':[surge_price*0.101], 
                             'req_long_rate_dec':[req*long*rate*dec*0.091], 'req':1, 'long':long, 
                             'rate':rate, 'dec':dec, 'P':[acc_prob]})
        sim.acceptance_attributes = pd.concat([sim.acceptance_attributes,attr])

    
        if acc_prob > random.uniform(0, 1):
            return False
        else:
            return True
    


sim.make_and_run(f_driver_decline=f_decline)
# Out:
# 20-11-21 17:20:46-WARNING-pax    4  got rejected by vehicle 11               2021-11-20 14:40:54
# 20-11-21 17:20:46-WARNING-pax    4  got rejected by vehicle 18               2021-11-20 14:40:54
# 20-11-21 17:20:46-WARNING-pax    7  got rejected by vehicle 16               2021-11-20 14:42:51
# 20-11-21 17:20:46-WARNING-pax   11  got rejected by vehicle 19               2021-11-20 14:44:19
# 20-11-21 17:20:46-WARNING-pax   12  got rejected by vehicle 6                2021-11-20 14:44:28
# 20-11-21 17:20:46-WARNING-pax   12  got rejected by vehicle 11               2021-11-20 14:44:28
# 20-11-21 17:20:47-WARNING-pax   36  got rejected by vehicle 20               2021-11-20 15:02:33
# 20-11-21 17:20:47-WARNING-pax   43  got rejected by vehicle 14               2021-11-20 15:05:17
# 20-11-21 17:20:47-WARNING-pax   49  got rejected by vehicle 6                2021-11-20 15:10:26
# 20-11-21 17:20:47-WARNING-pax   51  got rejected by vehicle 19               2021-11-20 15:11:58
# 20-11-21 17:20:47-WARNING-pax   54  got rejected by vehicle 12               2021-11-20 15:14:46
# 20-11-21 17:20:47-WARNING-pax   62  got rejected by vehicle 8                2021-11-20 15:20:44
# 20-11-21 17:20:47-WARNING-pax   62  got rejected by vehicle 2                2021-11-20 15:20:44
# 20-11-21 17:20:48-WARNING-pax   66  got rejected by vehicle 14               2021-11-20 15:22:01
# 20-11-21 17:20:48-WARNING-pax   72  got rejected by vehicle 18               2021-11-20 15:24:22
# 20-11-21 17:20:48-WARNING-pax   81  got rejected by vehicle 15               2021-11-20 15:29:02
# 20-11-21 17:20:48-WARNING-pax   97  got rejected by vehicle 16               2021-11-20 15:35:57
# 20-11-21 17:20:48-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 18
# 20-11-21 17:20:48-WARNING-pax  101  got rejected by vehicle 5                2021-11-20 15:38:58
# 20-11-21 17:20:48-WARNING-pax  101  got rejected by vehicle 15               2021-11-20 15:38:58
# 20-11-21 17:20:48-WARNING-pax  108  got rejected by vehicle 16               2021-11-20 15:43:07
# 20-11-21 17:20:48-WARNING-pax  111  got rejected by vehicle 12               2021-11-20 15:45:00
# 20-11-21 17:20:48-WARNING-pax  112  got rejected by vehicle 1                2021-11-20 15:45:34
# 20-11-21 17:20:49-WARNING-pax  125  got rejected by vehicle 4                2021-11-20 15:52:14
# 20-11-21 17:20:49-WARNING-pax  125  got rejected by vehicle 13               2021-11-20 15:52:50
# 20-11-21 17:20:49-WARNING-pax  126  got rejected by vehicle 13               2021-11-20 15:52:50
# 20-11-21 17:20:49-WARNING-Nobody likes each other, Qs 1veh; 2req; tabu 26
# 20-11-21 17:20:49-WARNING-pax  126  got rejected by vehicle 5                2021-11-20 15:54:16
# 20-11-21 17:20:49-WARNING-pax  130  got rejected by vehicle 5                2021-11-20 15:54:16
# 20-11-21 17:20:49-WARNING-pax  134  got rejected by vehicle 14               2021-11-20 15:56:41
# 20-11-21 17:20:49-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 29
# 20-11-21 17:20:49-WARNING-pax  135  got rejected by vehicle 14               2021-11-20 15:57:19
# 20-11-21 17:20:49-WARNING-Nobody likes each other, Qs 1veh; 2req; tabu 30
# 20-11-21 17:20:49-WARNING-pax  135  got rejected by vehicle 10               2021-11-20 15:57:23
# 20-11-21 17:20:49-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 31
# 20-11-21 17:20:49-WARNING-pax  139  got rejected by vehicle 9                2021-11-20 15:59:10
# 20-11-21 17:20:49-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 32
# 20-11-21 17:20:49-WARNING-pax  144  got rejected by vehicle 4                2021-11-20 16:05:19
# 20-11-21 17:20:49-WARNING-pax  146  got rejected by vehicle 13               2021-11-20 16:06:43
# 20-11-21 17:20:49-WARNING-pax  146  got rejected by vehicle 6                2021-11-20 16:06:43
# 20-11-21 17:20:49-WARNING-pax  147  got rejected by vehicle 13               2021-11-20 16:06:44
# 20-11-21 17:20:49-WARNING-pax  150  got rejected by vehicle 3                2021-11-20 16:09:50
# 20-11-21 17:20:49-WARNING-pax  150  got rejected by vehicle 7                2021-11-20 16:09:50
# 20-11-21 17:20:49-WARNING-pax  153  got rejected by vehicle 13               2021-11-20 16:11:36
# 20-11-21 17:20:50-WARNING-pax  162  got rejected by vehicle 16               2021-11-20 16:19:20
# 20-11-21 17:20:50-WARNING-pax  165  got rejected by vehicle 13               2021-11-20 16:20:10
# 20-11-21 17:20:50-WARNING-pax  168  got rejected by vehicle 20               2021-11-20 16:22:31
# 20-11-21 17:20:50-WARNING-pax  171  got rejected by vehicle 14               2021-11-20 16:24:02
# 20-11-21 17:20:50-WARNING-pax  184  got rejected by vehicle 20               2021-11-20 16:28:40
# 20-11-21 17:20:50-WARNING-pax  184  got rejected by vehicle 7                2021-11-20 16:28:40
# 20-11-21 17:20:50-WARNING-Nobody likes each other, Qs 2veh; 1req; tabu 45
# 20-11-21 17:20:50-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 45
# 20-11-21 17:20:50-WARNING-pax  186  got rejected by vehicle 20               2021-11-20 16:29:04
# 20-11-21 17:20:50-WARNING-Nobody likes each other, Qs 1veh; 2req; tabu 46
# 20-11-21 17:20:50-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 46
# 20-11-21 17:20:50-WARNING-pax  184  got rejected by vehicle 19               2021-11-20 16:29:08
# 20-11-21 17:20:50-WARNING-Nobody likes each other, Qs 2veh; 1req; tabu 47
# 20-11-21 17:20:50-WARNING-pax  196  got rejected by vehicle 1                2021-11-20 16:34:38
# 20-11-21 17:20:50-WARNING-pax  201  got rejected by vehicle 7                2021-11-20 16:38:32
# 20-11-21 17:20:51-WARNING-pax  203  got rejected by vehicle 2                2021-11-20 16:42:34
# 20-11-21 17:20:51-WARNING-pax  203  got rejected by vehicle 13               2021-11-20 16:44:56
# 20-11-21 17:20:51-WARNING-pax  216  got rejected by vehicle 16               2021-11-20 16:48:05
# 20-11-21 17:20:51-WARNING-pax  222  got rejected by vehicle 10               2021-11-20 16:51:04
# 20-11-21 17:20:51-WARNING-pax  228  got rejected by vehicle 5                2021-11-20 16:56:48
# 20-11-21 17:20:51-WARNING-pax  233  got rejected by vehicle 2                2021-11-20 16:59:02
# 20-11-21 17:20:51-WARNING-pax  237  got rejected by vehicle 10               2021-11-20 17:01:15
# 20-11-21 17:20:51-WARNING-pax  244  got rejected by vehicle 11               2021-11-20 17:03:53
# 20-11-21 17:20:51-WARNING-pax  250  got rejected by vehicle 14               2021-11-20 17:05:59
# 20-11-21 17:20:52-WARNING-pax  255  got rejected by vehicle 7                2021-11-20 17:10:42
# 20-11-21 17:20:52-WARNING-pax  265  got rejected by vehicle 16               2021-11-20 17:19:15
# 20-11-21 17:20:52-WARNING-pax  267  got rejected by vehicle 19               2021-11-20 17:19:43
# 20-11-21 17:20:52-WARNING-pax  269  got rejected by vehicle 19               2021-11-20 17:20:26
# 20-11-21 17:20:52-WARNING-pax  269  got rejected by vehicle 18               2021-11-20 17:20:26
# 20-11-21 17:20:52-WARNING-pax  269  got rejected by vehicle 5                2021-11-20 17:20:26
# 20-11-21 17:20:52-WARNING-pax  271  got rejected by vehicle 19               2021-11-20 17:20:59
# 20-11-21 17:20:52-WARNING-pax  273  got rejected by vehicle 19               2021-11-20 17:21:58
# 20-11-21 17:20:52-WARNING-pax  274  got rejected by vehicle 19               2021-11-20 17:22:16
# 20-11-21 17:20:52-WARNING-pax  282  got rejected by vehicle 16               2021-11-20 17:26:45
# 20-11-21 17:20:52-WARNING-pax  283  got rejected by vehicle 1                2021-11-20 17:27:55
# 20-11-21 17:20:52-WARNING-pax  286  got rejected by vehicle 16               2021-11-20 17:28:54
# 20-11-21 17:20:52-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 70
# 20-11-21 17:20:52-WARNING-pax  286  got rejected by vehicle 3                2021-11-20 17:28:59
# 20-11-21 17:20:52-WARNING-Nobody likes each other, Qs 2veh; 1req; tabu 71
# 20-11-21 17:20:52-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 71
# 20-11-21 17:20:52-WARNING-pax  290  got rejected by vehicle 20               2021-11-20 17:31:19
# 20-11-21 17:20:52-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 72
# 20-11-21 17:20:53-WARNING-pax  292  got rejected by vehicle 7                2021-11-20 17:32:10
# 20-11-21 17:20:53-WARNING-pax  299  got rejected by vehicle 16               2021-11-20 17:36:23
# 20-11-21 17:20:53-WARNING-pax  299  got rejected by vehicle 13               2021-11-20 17:36:23
# 20-11-21 17:20:53-WARNING-pax  299  got rejected by vehicle 4                2021-11-20 17:36:23
# 20-11-21 17:20:53-WARNING-pax  302  got rejected by vehicle 13               2021-11-20 17:37:18
# 20-11-21 17:20:53-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 77
# 20-11-21 17:20:53-WARNING-pax  302  got rejected by vehicle 6                2021-11-20 17:37:59
# 20-11-21 17:20:53-WARNING-Nobody likes each other, Qs 2veh; 1req; tabu 78
# 20-11-21 17:20:53-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 78
# 20-11-21 17:20:53-WARNING-pax  302  got rejected by vehicle 9                2021-11-20 17:38:45
# 20-11-21 17:20:53-WARNING-Nobody likes each other, Qs 2veh; 1req; tabu 79
# 20-11-21 17:20:53-WARNING-pax  307  got rejected by vehicle 17               2021-11-20 17:40:58
# 20-11-21 17:20:53-WARNING-pax  307  got rejected by vehicle 8                2021-11-20 17:40:58
# 20-11-21 17:20:53-WARNING-pax  310  got rejected by vehicle 16               2021-11-20 17:42:20
# 20-11-21 17:20:53-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 82
# 20-11-21 17:20:53-WARNING-pax  323  got rejected by vehicle 11               2021-11-20 17:50:39
# 20-11-21 17:20:53-WARNING-pax  327  got rejected by vehicle 17               2021-11-20 17:52:08
# 20-11-21 17:20:53-WARNING-pax  330  got rejected by vehicle 19               2021-11-20 17:52:34
# 20-11-21 17:20:53-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 85
# 20-11-21 17:20:53-WARNING-pax  332  got rejected by vehicle 16               2021-11-20 17:53:54
# 20-11-21 17:20:54-WARNING-pax  347  got rejected by vehicle 18               2021-11-20 17:58:47
# 20-11-21 17:20:54-WARNING-pax  348  got rejected by vehicle 6                2021-11-20 18:00:45
# 20-11-21 17:20:54-WARNING-pax  356  got rejected by vehicle 1                2021-11-20 18:06:38
# 20-11-21 17:20:54-WARNING-pax  363  got rejected by vehicle 17               2021-11-20 18:07:56
# 20-11-21 17:20:54-WARNING-pax  361  got rejected by vehicle 13               2021-11-20 18:08:04
# 20-11-21 17:20:54-WARNING-pax  359  got rejected by vehicle 19               2021-11-20 18:11:31
# 20-11-21 17:20:54-WARNING-pax  371  got rejected by vehicle 9                2021-11-20 18:14:39
# 20-11-21 17:20:54-WARNING-pax  376  got rejected by vehicle 17               2021-11-20 18:17:07
# 20-11-21 17:20:54-WARNING-pax  375  got rejected by vehicle 17               2021-11-20 18:17:07
# 20-11-21 17:20:54-WARNING-pax  382  got rejected by vehicle 11               2021-11-20 18:18:45
# 20-11-21 17:20:55-WARNING-pax  386  got rejected by vehicle 18               2021-11-20 18:21:00
# 20-11-21 17:20:55-WARNING-pax  384  got rejected by vehicle 16               2021-11-20 18:22:18
# 20-11-21 17:20:55-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 98
# 20-11-21 17:20:55-WARNING-pax  391  got rejected by vehicle 19               2021-11-20 18:26:41
# 20-11-21 17:20:55-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 99
# 20-11-21 17:20:55-WARNING-pax  391  got rejected by vehicle 9                2021-11-20 18:27:00
# 20-11-21 17:20:55-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 100
# 20-11-21 17:20:55-WARNING-pax  406  got rejected by vehicle 20               2021-11-20 18:38:33
# 20-11-21 17:20:55-WARNING-pax  408  got rejected by vehicle 3                2021-11-20 18:40:58
# 20-11-21 17:20:55-WARNING-pax  412  got rejected by vehicle 19               2021-11-20 18:43:16
# 20-11-21 17:20:55-WARNING-pax  415  got rejected by vehicle 1                2021-11-20 18:44:00
# 20-11-21 17:20:55-WARNING-pax  416  got rejected by vehicle 10               2021-11-20 18:44:17
# 20-11-21 17:20:55-WARNING-pax  424  got rejected by vehicle 16               2021-11-20 18:48:44
# 20-11-21 17:20:56-WARNING-pax  429  got rejected by vehicle 19               2021-11-20 18:53:44
# 20-11-21 17:20:56-WARNING-pax  438  got rejected by vehicle 4                2021-11-20 18:55:58
# 20-11-21 17:20:56-WARNING-pax  437  got rejected by vehicle 4                2021-11-20 18:55:58
# 20-11-21 17:20:56-WARNING-pax  439  got rejected by vehicle 13               2021-11-20 18:57:43
# 20-11-21 17:20:56-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 110
# 20-11-21 17:20:56-WARNING-pax  444  got rejected by vehicle 7                2021-11-20 18:59:28
# 20-11-21 17:20:56-WARNING-pax  457  got rejected by vehicle 4                2021-11-20 19:14:43
# 20-11-21 17:20:56-WARNING-pax  468  got rejected by vehicle 20               2021-11-20 19:20:05
# 20-11-21 17:20:56-WARNING-pax  468  got rejected by vehicle 16               2021-11-20 19:20:05
# 20-11-21 17:20:56-WARNING-pax  470  got rejected by vehicle 9                2021-11-20 19:21:10
# 20-11-21 17:20:57-WARNING-pax  479  got rejected by vehicle 13               2021-11-20 19:24:26
# 20-11-21 17:20:57-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 116
# 20-11-21 17:20:57-WARNING-pax  481  got rejected by vehicle 13               2021-11-20 19:24:55
# 20-11-21 17:20:57-WARNING-Nobody likes each other, Qs 1veh; 2req; tabu 117
# 20-11-21 17:20:57-WARNING-pax  479  got rejected by vehicle 10               2021-11-20 19:25:03
# 20-11-21 17:20:57-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 118
# 20-11-21 17:20:57-WARNING-pax  483  got rejected by vehicle 16               2021-11-20 19:26:07
# 20-11-21 17:20:57-WARNING-Nobody likes each other, Qs 1veh; 1req; tabu 119
# 20-11-21 17:20:57-WARNING-pax  486  got rejected by vehicle 4                2021-11-20 19:30:21
# 20-11-21 17:20:57-WARNING-simulation time 11.3 s
# 20-11-21 17:20:58-WARNING-assertion tests for simulation results - passed

# %%
r_5050= ResultS(sim)

# %%
pd.DataFrame(sim.pax[1].rides)
# Out:
#    pax         pos    t                   event  veh_id
# 0    1  5367742079    0              STARTS_DAY     NaN
# 1    1  5367742079   20           REQUESTS_RIDE     NaN
# 2    1  5367742079   20          RECEIVES_OFFER     NaN
# 3    1  5367742079   35           ACCEPTS_OFFER     NaN
# 4    1  5367742079   55       ARRIVES_AT_PICKUP     1.0
# 5    1  5367742079  149  MEETS_DRIVER_AT_PICKUP     1.0
# 6    1  5367742079  179     DEPARTS_FROM_PICKUP     1.0
# 7    1  1436427159  825      ARRIVES_AT_DROPOFF     1.0
# 8    1  1436427159  835       SETS_OFF_FOR_DEST     NaN
# 9    1  1436427159  835         ARRIVES_AT_DEST     NaN

# %%
pd.DataFrame(sim.pax[1].rides)
# Out:
#    pax         pos     t                   event  veh_id
# 0    1  5367742079     0              STARTS_DAY     NaN
# 1    1  5367742079    20           REQUESTS_RIDE     NaN
# 2    1  5367742079    20          RECEIVES_OFFER     NaN
# 3    1  5367742079    35           ACCEPTS_OFFER     NaN
# 4    1  5367742079    55       ARRIVES_AT_PICKUP     3.0
# 5    1  5367742079   390  MEETS_DRIVER_AT_PICKUP     3.0
# 6    1  5367742079   420     DEPARTS_FROM_PICKUP     3.0
# 7    1  1436427159  1066      ARRIVES_AT_DROPOFF     3.0
# 8    1  1436427159  1076       SETS_OFF_FOR_DEST     NaN
# 9    1  1436427159  1076         ARRIVES_AT_DEST     NaN

# %%
sim.pax[1].pax
# Out:
# pos                              1436427159
# event        travellerEvent.ARRIVES_AT_DEST
# platforms                               [0]
# rate                               3.695493
# Name: 1, dtype: object

# %%
sim.pax[1].pax
# Out:
# pos                              1436427159
# event        travellerEvent.ARRIVES_AT_DEST
# platforms                               [0]
# rate                               3.695493
# Name: 1, dtype: object
