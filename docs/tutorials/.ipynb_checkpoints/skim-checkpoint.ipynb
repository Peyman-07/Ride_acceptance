# %%
import os, sys # add MaaSSim to path (not needed if MaaSSim is already in path)
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import MaaSSim

# %%
#!pip install MaaSSim
import MaaSSim.utils
import logging
from dotmap import DotMap
import MaaSSim.simulators
from MaaSSim.data_structures import structures as inData
from MaaSSim.acceptance import ResultS

# %%
import osmnx as ox
import networkx as nx
import random
import pandas as pd
import matplotlib.pyplot as plt          
import numpy as np
import seaborn as sns

# %%
# Do not forget to set the radius for centeral nodes calculation
# The minimum trip distance is considered 1000m and this can be modified through utils.py: generate_demand function. 
# long attribute should be calculated according to the size of city
# Platform fare is 2$ per km

params = MaaSSim.utils.get_config('glance.json')
params.use_fixed_postions = True
params.times.patience = 600 #in second
params.dist_threshold = 10000 #in meter
params.vehicle_fixed_positions= True  #this should be fixed
params.city = "Delft, Netherlands"
params.paths.G = "../../data/graphs/Delft.graphml"
params.paths.skim = "../../data/graphs/Delft.csv"
params.paths.ride_skim = "../../data/graphs/Delft_ride.csv"
params.nP = 5
params.nV = 2
params.simTime =1

# %%
sim= MaaSSim.simulators.simulate(params=params, logger_level = logging.WARNING)
# Out:
# 15-11-21 17:14:14-WARNING-Setting up 1h simulation at 2021-11-15 16:47:59 for 2 vehicles and 5 passengers in Delft, Netherlands
# 15-11-21 17:14:14-WARNING-simulation time 0.1 s
# 15-11-21 17:14:14-WARNING-assertion tests for simulation results - passed

# %%
sim.inData.stats.central_radius
# Out:
# 1000

# %%
len(sim.inData.stats.central_nodes)
# Out:
# 173

# %%
len(sim.inData.nodes)
# Out:
# 2156

# %%
==============================================================================================================

# %%
G = sim.inData.G

# %%
central_nodes = sim.inData.stats.central_nodes
nodes, edges = ox.graph_to_gdfs(G)
index = edges.index
edges['speed'] = params.speeds.ride
#edges

# %%
#modify the speed for cenrtal edges
for i in index:
    if i[0] in central_nodes or i[1] in central_nodes:
        edges.at[i,'speed'] = 3

# %%
edges['travel_time'] = edges['length'] / edges['speed']

# %%
new_G = ox.utils_graph.graph_from_gdfs(nodes, edges)

# %%
fig, ax = ox.plot_graph(new_G, figsize=(10, 10), show=False, close=False, node_size=20, bgcolor='black', edge_color='w')

# %%
params.city
# Out:
# 'Delft, Netherlands'

# %%
params.city = 'Delft, Netherlands'
MaaSSim.utils.make_config_paths(params, main=None, rel = False)
# Out:
# DotMap(NAME='default', city='Delft, Netherlands', nP=5, nV=2, times=DotMap(request=15, transaction=20, pickup=30, dropoff=10, patience=600, pickup_patience=90), speeds=DotMap(walk=1.2, ride=10), t0=Timestamp('2021-11-15 17:14:13'), paths=DotMap(G='/Users/aylar/Desktop/Farnoud/Ride_acceptance/data/graphs/Delft.graphml', skim='/Users/aylar/Desktop/Farnoud/Ride_acceptance/data/graphs/Delft.csv', _ipython_display_=DotMap(), _repr_mimebundle_=DotMap(), _repr_html_=DotMap(), _repr_markdown_=DotMap(), _repr_svg_=DotMap(), _repr_png_=DotMap(), _repr_pdf_=DotMap(), _repr_jpeg_=DotMap(), _repr_latex_=DotMap(), _repr_json_=DotMap(), _repr_javascript_=DotMap(), dumps='dump', ride_skim='../../data/graphs/Delft_ride.csv', main='/Users/aylar/Desktop/Farnoud/Ride_acceptance', data='/Users/aylar/Desktop/Farnoud/Ride_acceptance/data', params='/Users/aylar/Desktop/Farnoud/Ride_acceptance/data/configs', postcodes='/Users/aylar/Desktop/Farnoud/Ride_acceptance/data/postcodes/PC4_Nederland_2015.shp', albatross='/Users/aylar/Desktop/Farnoud/Ride_acceptance/data/albatross', sblt='/Users/aylar/Desktop/Farnoud/Ride_acceptance/data/sblt', NYC='/Users/aylar/Desktop/Farnoud/Ride_acceptance/data/fhv_tripdata_2018-01.csv'), dist_threshold=10000, big_time=10, sleep=False, simTime=1, demand_structure=DotMap(origins_dispertion=-0.0003, destinations_dispertion=-0.001, temporal_dispertion=0.3, temporal_distribution='uniform'), shareability=DotMap(windows=DotMap(pickup=[-2, 5], dropoff=[-10, 5]), avg_speed=10, shared_discount=0.8, VoT=0.005, WtS=1.2, delay_value=1.5, price=1.5, matching_obj='u_veh', pax_delay=45, horizon=600, max_degree=600, share=0, shape=DotMap()), parallel=DotMap(nThread=1, nReplications=2), nD=1, _ipython_display_=DotMap(), _repr_mimebundle_=DotMap(), _repr_html_=DotMap(), _repr_markdown_=DotMap(), _repr_svg_=DotMap(), _repr_png_=DotMap(), _repr_pdf_=DotMap(), _repr_jpeg_=DotMap(), _repr_latex_=DotMap(), _repr_json_=DotMap(), _repr_javascript_=DotMap(), use_fixed_postions=True, vehicle_fixed_positions=True, vehicles_fixed=DotMap())

# %%
inData.G = new_G
inData.nodes = pd.DataFrame.from_dict(dict(inData.G.nodes(data=True)), orient='index')

# %%
inData.skim_generator = nx.all_pairs_dijkstra_path_length(inData.G, weight='travel_time')
inData.skim_dict = dict(inData.skim_generator)  # filled dict is more usable
inData.skim = pd.DataFrame(inData.skim_dict).fillna(1500).T.astype(float)

# %%
ox.save_graphml(inData.G, filepath=params.paths.G)
inData.skim.to_csv(params.paths.ride_skim, chunksize=20000000)

# %%
params.paths.ride_skim
# Out:
# '../../data/graphs/Delft_ride.csv'

# %%
skim = inData.skim
skim
# Out:
#             1501364225  1402613311  1402613314  1501364218  1402613338  \
# 1501364225      0.0000      1.4888      2.1745      8.6030      9.7265
# 1402613311      2.2745      0.0000      0.6857     10.8775      8.2377
# 1501364218     75.9659     73.6914     74.3771      0.0000     81.9291
# 1269112834    902.4151    900.1406    900.8263    911.0181    908.3783
# 626146739     878.8482    876.5737    877.2594    887.4512    884.8114
# ...                ...         ...         ...         ...         ...
# 1668136728    834.9092    832.6347    833.3204    843.5122    840.8724
# 1668136731    822.2315    819.9570    820.6427    830.8345    828.1947
# 1668136738    824.9348    822.6603    823.3460    833.5378    830.8980
# 4261101421    572.8149    570.5404    571.2261    581.4179    578.7781
# 1516978128   1500.0000   1500.0000   1500.0000   1500.0000   1500.0000
#
#             1402613341  1402613343  1402613323  1402613322  44915445    ...  \
# 8576774075  271.567733  279.370400  280.059400  281.131733  261.649733
#
#             444383792   444383782   444383786   444383802   443633159   ...  \
# 313615304    10.720000   15.468333   17.370667   24.644667   27.573333  ...
# 444614775    20.638000   25.386333   27.288667   34.562667   37.491333  ...
# 444383798     2.917333    7.665667    9.568000   16.842000   19.770667  ...
# 313616275   301.081600  298.395667  297.857700  285.029667  312.560833  ...
# 5877942322  449.329267  446.643333  446.105367  433.277333  460.808500  ...
# ...                ...         ...         ...         ...         ...  ...
# 8174334562  157.569833  162.318167  164.220500  171.494500  152.407667  ...
# 8192037819  162.959033  167.707367  169.609700  176.883700  141.649033  ...
# 8195326624  162.017033  166.765367  168.667700  175.941700  156.854867  ...
# 8382246963  345.740367  350.488700  352.391033  359.665033  324.430367  ...
# 8576774075  282.287733  287.036067  287.635833  296.212400  277.125567  ...
#
#              1683010890   1683012001   1683011696   6086720300   6086720389  \
# 313615304    808.381267   816.777867   829.835567   838.038567   856.826067
# 444614775    818.299267   826.695867   839.753567   847.956567   866.744067
# 444383798    800.578600   808.975200   822.032900   830.235900   849.023400
# 313616275    813.051167   821.447767   834.505467   842.708467   894.728767
# 5877942322   664.803500   673.200100   686.257800   694.460800   746.481100
# ...                 ...          ...          ...          ...          ...
# 8174334562   889.658867   898.055467   911.113167   919.316167   938.103667
# 8192037819   680.203100   688.599700   701.657400   709.860400   728.647900
# 8195326624   884.387967   892.784567   905.842267   914.045267   932.832767
# 8382246963  1045.114267  1053.510867  1066.568567  1074.771567  1093.559067
# 8576774075   926.839500   935.236100   948.293800   956.496800  1008.517100
#
#              1683010800   4687619981   6086720316   6086720403   6086720419
# 313615304    861.203967   872.720367   879.705167   904.396167   929.943267
# 444614775    871.121967   882.638367   889.623167   914.314167   939.861267
# 444383798    853.401300   864.917700   871.902500   896.593500   922.140600
# 313616275    865.873867   990.876967   884.375067   909.066067   934.613167
# 5877942322   717.626200   842.629300   736.127400   760.818400   786.365500
# ...                 ...          ...          ...          ...          ...
# 8174334562   942.481567   953.997967   960.982767   985.673767  1011.220867
# 8192037819   733.025800   744.542200   751.527000   776.218000   801.765100
# 8195326624   937.210667   948.727067   955.711867   980.402867  1005.949967
# 8382246963  1097.936967  1109.453367  1116.438167  1141.129167  1166.676267
# 8576774075   979.662200  1078.715867   998.163400  1022.854400  1048.401500
#
# [652 rows x 652 columns]

# %%
skim.T[1501364218][1501364225]
# Out:
# 75.96589999999999

# %%
int(nx.shortest_path_length(new_G, 1501364218, 1501364225, weight='travel_time',method='dijkstra'))
# Out:
# 75

# %%
https://stackoverflow.com/questions/59692619/generate-weighted-graph-from-osmnx-for-networkx
    
https://stackoverflow.com/questions/56308298/how-to-get-the-weight-of-the-smallest-path-between-two-nodes
    
https://automating-gis-processes.github.io/site/notebooks/L6/network-analysis.html
# Out:
#   File "<ipython-input-33-b7ab0f05dbcd>", line 1
#     https://stackoverflow.com/questions/59692619/generate-weighted-graph-from-osmnx-for-networkx
#           ^
# SyntaxError: invalid syntax
